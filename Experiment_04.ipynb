# %%
import cv2
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
img=cv2.imread('input.jpg')
big=cv2.resize(img,None,fx=2.0,fy=2)
small=cv2.resize(img,None,fx=0.5,fy=0.5)
cv2.imwrite("big.jpg",big)
cv2.imwrite("small.jpg",small)
# Out:
# True

# %%
from IPython.display import Image; Image("big.jpg")

# %%
from IPython.display import Image; Image("small.jpg")
