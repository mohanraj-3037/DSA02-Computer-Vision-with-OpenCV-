# %%
import cv2
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
img=cv2.imread("input.jpg")
out=np.roll(img,30,0)
rig=np.roll(out,50,1)
cv2.imwrite("changed.jpg",rig)
plt.imshow(rig)
pli
