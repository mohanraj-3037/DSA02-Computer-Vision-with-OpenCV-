# %%
import cv2
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import cv2

v=cv2.VideoCapture("2.mp4.mp4")
fps,w,h=v.get(5),int(v.get(3)),int(v.get(4))

for f,n in [(2,"fast.mp4"),
\(.5,"slow.mp4")]:
    v.set(1,0)
    o=cv2.VideoWriter(n,cv2.VideoWriter_fourcc(*'mp4v'),fps*f,(w,h))
    while True:
        r,frm=v.read()
        if not r: break
        o.write(frm)
    o.release()

v.release()

# %%
from IPython.display import Video; Video("fast.mp4")
# Out:
# <video src="fast.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
from IPython.display import Video; Video("slow.mp4")
# Out:
# <video src="slow.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>
