# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread("input.jpg")
h, w = img.shape[:2]
src = np.float32([[0,0], [w-1,0], [w-1,h-1], [0,h-1]])
dst = np.float32([[50,50], [w-100,30], [w-50,h-50], [70,h-80]])
H, _ = cv2.findHomography(src, dst)
out = cv2.warpPerspective(img, H, (w, h))

plt.imshow(out[:, :, ::-1])
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(716.5), np.float64(541.5), np.float64(-0.5))
