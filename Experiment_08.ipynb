# %%
import cv2
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
cv2.imread("input.jpg")

src=np.float32([[0,0] ,[w-1,0][w-1,h-1],[0,h-1]])
aff=np.float32([[50,50],[w-100,30],[w-50,h-50],[70,h-80]])
M=cv2.getPerspectiveTransform(src,aff)
out=cv2.warpPerspective(img,M,(w,h))
plt.imshow(out[: ,: ,::-1])
plt.axis("off")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 src=np.float32([[0,0] ,[w-1,0][w-1,h-1],[0,h-1]])
#       2 aff=np.float32([[50,50],[w-100,30],[w-50,h-50],[70,h-80]])
#       3 M=cv2.getPerspectiveTransform(src,aff)
#
# NameError: name 'w' is not defined
